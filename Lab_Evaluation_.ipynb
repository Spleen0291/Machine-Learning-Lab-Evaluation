# %%
# !pip install pycaret
print("Successfully installed PyCaret")

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/content/Fuel_cell_performance_data-Full.csv")
print(df)
# Out:
#        F1    F2    F3     F4      F5    F6     F7     F8   F9   F10      F11  \
# 0    52.9  1.33  49.1  37.13  129.43  35.0  0.281  112.7  207  0.55   98.971
# 1    87.6  2.12  48.8  42.10  171.07  37.6  0.153  157.4  188  0.86  101.179
# 2    73.3  2.72  93.8  20.11  163.69  44.3  0.367  348.7  270  1.87   98.919
# 3    65.6  2.58  48.1  35.11   63.37  32.5  0.279  321.2  322  1.75  101.560
# 4    39.6  2.58  49.3  32.93   63.40  47.0  0.149  205.6  203  1.55   98.148
# ..    ...   ...   ...    ...     ...   ...    ...    ...  ...   ...      ...
# 995  35.7  2.35  90.8  27.08  187.90  42.7  0.274  185.1  299  1.47  102.654
# 996  83.2  2.92  41.0  24.22   60.14  38.2  0.300  157.5   97  1.17   99.714
# 997  37.3  1.16  51.9  25.37   92.78  43.3  0.385  237.6  166  0.72  100.844
# 998  87.8  1.15  50.8  30.04  168.43  35.8  0.205  382.3  276  1.22  100.460
# 999  55.5  1.51  88.4  16.22  136.05  28.5  0.287  136.8   82  0.55  103.686
#
# ...

# %%
from pycaret.regression import *
s = setup(data = df, target="Target3", train_size=0.7, ignore_features=["Target1","Target2","Target4","Target5"])
# Out:
# <style type="text/css">
# #T_e6661_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e6661" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6661_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e6661_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6661_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6661_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e6661_row0_col1" class="data row0 col1" >6457</td>
#     </tr>
#     <tr>
#       <th id="T_e6661_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6661_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e6661_row1_col1" class="data row1 col1" >Target3</td>
#     </tr>
#     <tr>
#       <th id="T_e6661_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm = compare_models()
# Out:
# <style type="text/css">
# #T_48972 th {
#   text-align: left;
# }
# ...
